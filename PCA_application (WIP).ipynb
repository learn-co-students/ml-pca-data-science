# %% [markdown]
# ## 4. Example  (WIP)

# %%
import pandas as pd

ratings = pd.read_csv('ratings.csv')

# %%
id = pd.Series(ratings["movieId"], dtype="category")

id.value_counts().head(100)
==> take the 100 most popular movies and their ratings
# Out:
# 356      341
# 296      324
# 318      311
# 593      304
# 260      291
# 480      274
# 2571     259
# 1        247
# 527      244
# 589      237
# 1196     234
# 110      228
# 1270     226
# 608      224
# 1198     220
# 2858     220
# 780      218
# 1210     217
# 588      215
# 457      213
# 2959     202
# 590      202
# 47       201
# 50       201
# 4993     200
# 858      200
# 364      200
# 150      200
# 380      198
# 32       196
#         ...
# 4226     132
# 1089     132
# 293      132
# 1213     131
# 4886     130
# 4963     130
# 586      129
# 153      129
# 3793     127
# 1214     127
# 587      126
# 8961     126
# 2997     126
# 4973     125
# 3114     125
# 253      125
# 1617     125
# 1200     125
# 539      125
# 778      124
# 924      123
# 1923     123
# 6377     122
# 10       122
# 357      122
# 1206     121
# 2396     121
# 58559    121
# 1732     120
# 39       120
# Name: movieId, Length: 100, dtype: int64

# %%
import pandas as pd

movies_all = pd.read_csv('movies.csv')

movies_all.iloc[589]
# Out:
# movieId                  695
# title      True Crime (1996)
# genres      Mystery|Thriller
# Name: 589, dtype: object

# %%
comedies = movies_all.loc[movies_all['genres']=="Comedy"]

movies_all
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# 5           6                                        Heat (1995)
# 6           7                                     Sabrina (1995)
# 7           8                                Tom and Huck (1995)
# 8           9                                Sudden Death (1995)
# 9          10                                   GoldenEye (1995)
# 10         11                     American President, The (1995)
# 11         12                 Dracula: Dead and Loving It (1995)
# 12         13                                       Balto (1995)
# ...

# %%
rom_com_doc = movies_all.loc[movies_all['genres'].isin(["Romance", "Comedy", "Documentary"])]

rom = movies_all.loc[movies_all['genres'].isin(["Drama"])]

# %%
rom
# Out:
#       movieId                                           title genres
# 13         14                                    Nixon (1995)  Drama
# 25         26                                  Othello (1995)  Drama
# 30         31                          Dangerous Minds (1995)  Drama
# 38         40                 Cry, the Beloved Country (1995)  Drama
# 41         43                              Restoration (1995)  Drama
# 52         55                                  Georgia (1995)  Drama
# 53         57                    Home for the Holidays (1995)  Drama
# 58         62                       Mr. Holland's Opus (1995)  Drama
# 104       114                        Margaret's Museum (1995)  Drama
# 109       121                 Boys of St. Vincent, The (1992)  Drama
# 112       124  Star Maker, The (Uomo delle stelle, L') (1995)  Drama
# 116       130                                   Angela (1995)  Drama
# 126       147                  Basketball Diaries, The (1995)  Drama
# ...

# %% [markdown]
# # Sources

# %% [markdown]
# http://www.bbk.ac.uk/ems/faculty/brooms/teaching/SMDA/SMDA-02.pdf

# %% [markdown]
# https://stackoverflow.com/questions/13224362/principal-component-analysis-pca-in-python
